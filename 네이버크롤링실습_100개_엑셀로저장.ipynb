# %% [markdown]
# <a href="https://colab.research.google.com/github/jyoon0319/2023S/blob/main/%EB%84%A4%EC%9D%B4%EB%B2%84%ED%81%AC%EB%A1%A4%EB%A7%81%EC%8B%A4%EC%8A%B5_100%EA%B0%9C_%EC%97%91%EC%85%80%EB%A1%9C%EC%A0%80%EC%9E%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#원래 1페이지에서 100개보여주기 코드
import os
import sys
import urllib.request

#client_id = '본인이 발급받은 네이버 Client ID'
#client_secret = '본인이 발급받은 네이버 Client Secret'

search_text = urllib.parse.quote("프로 러")

page_start = 1
display = 100


url = "https://openapi.naver.com/v1/search/blog?query=%s&start=%s&display=%s" %(search_text, page_start, display) # JSON 결과
#url = "https://openapi.naver.com/v1/search/blog.xml?query=%s&start=%s&display=%s" %(search_text, page_start, display) # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
#    print(len(response_body))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 19 Apr 2023 23:19:59 +0900",
# 	"total":45171,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"&lt;<b>프로<\/b>지출러&gt;에서 &lt;<b>프로<\/b>저축러&gt; 로! - 현명한 주부가 되기 위한... ",
# 			"link":"https:\/\/blog.naver.com\/paris_luv\/223000333905",
# 			"description":"그렇게 &lt;<b>프로<\/b>지출러&gt;로써 '소비' 를 행복이라 여기며 살던 내가 &lt;<b>프로<\/b>저축러&gt; 의 삶으로 전환점을 맞이하게 된 계기가 제주 이사 이다. 일단 제주에는 나의 가장 큰 지출 목록을 차지했던 백화점이 없었다.... ",
# 			"bloggername":"Le Petit Trianon",
# 			"bloggerlink":"blog.naver.com\/paris_luv",
# 			"postdate":"20230131"
# 		},
# 		{
# 			"title":"<b>프로<\/b>자기탐색러가 되기로 마음 먹은 이유",
# 			"link":"https:\/\/blog.naver.com\/thddl_9601\/222420996124",
# 			"description":"이상, 2021년 7월 <b>프로<\/b>자기탐색러로서 새로운 시작을 알리며, 자기발견에 진심인 songyi 였습니다! 모두 건강하고 충만하게 누리는 7월이 되시길 바랍니다❤ 세 가지 질문으로 '나'를 알 수 있다고?",
# 			"bloggername":"SING A SONGYI",
# 			"bloggerlink":"blog.naver.com\/thddl_9601",
# 			"postdate":"20210705"
# 		},
# 		{
# ...

# %%
#결과물 response_body 타입확인
print(type(response_body))

#결과물을 json으로 변환
import json
jsonObj = json.loads(response_body.decode('utf-8'))
print(type(jsonObj))
print(jsonObj)
# Out:
# <class 'bytes'>
# <class 'dict'>
# ...

# %%
#딕셔너리를 데이터프레임으로 변한하기
import pandas as pd
df = pd.DataFrame(jsonObj)
type(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   lastBuildDate  100 non-null    object
#  1   total          100 non-null    int64
#  2   start          100 non-null    int64
#  3   display        100 non-null    int64
#  4   items          100 non-null    object
# dtypes: int64(3), object(2)
# memory usage: 4.0+ KB

# %%
df
# Out:
#                       lastBuildDate  total  start  display  \
# 0   Wed, 19 Apr 2023 23:19:59 +0900  45171      1      100
# 1   Wed, 19 Apr 2023 23:19:59 +0900  45171      1      100
# 2   Wed, 19 Apr 2023 23:19:59 +0900  45171      1      100
# 3   Wed, 19 Apr 2023 23:19:59 +0900  45171      1      100
# 4   Wed, 19 Apr 2023 23:19:59 +0900  45171      1      100
# ..                              ...    ...    ...      ...
# 95  Wed, 19 Apr 2023 23:19:59 +0900  45171      1      100
# 96  Wed, 19 Apr 2023 23:19:59 +0900  45171      1      100
# 97  Wed, 19 Apr 2023 23:19:59 +0900  45171      1      100
# 98  Wed, 19 Apr 2023 23:19:59 +0900  45171      1      100
# 99  Wed, 19 Apr 2023 23:19:59 +0900  45171      1      100
#
#                                                 items
# 0   {'title': '&lt;<b>프로</b>지출러&gt;에서 &lt;<b>프로</b...
# 1   {'title': '<b>프로</b>자기탐색러가 되기로 마음 먹은 이유', 'lin...
# 2   {'title': '의정부 용현동 헬스 추천 새해 준비하는 <b>프로</b> 다이어...
# ...

# %%
#엑셀로 저장하기

result1 = df.to_excel('hundred.xlsx')
