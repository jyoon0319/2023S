# %% [markdown]
# <a href="https://colab.research.google.com/github/jyoon0319/2023S/blob/main/Morphology_HW_discussion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Morphology - Word Structure

# %% [markdown]
# #Let's use graphviz
# 원본코드:
# # https://graphviz.readthedocs.io/en/stable/examples.html#hello-py

# %%
import graphviz

g = graphviz.Digraph('G', filename='hello.gv')

g.edge('Hello', 'World')

g

# %%
import graphviz

g = graphviz.Digraph('G', filename='hello.gv')

g.edge('A', 'B')
g.edge('B', 'C')
g.edge('B', 'D')

g

# %% [markdown]
# ### Give it a try [Top-down]

# %%
import graphviz

g = graphviz.Digraph('G', filename='hello.gv')

g.edge('thinkeners', 'N\nthickener')
g.edge('thinkeners', 's_b/s/i')
g.edge('N\nthickener', 'V\nthicken')
g.edge('N\nthickener', 'er_b/s/d')
g.edge('V\nthicken', 'A\nthick')
g.edge('V\nthicken', 'en_b/s/d')


g

# %% [markdown]
# # [Practice] Morphologival Analysis of Multiple-morpheme Words:
# paintings, deactivate, disappearances, irreplaceability

# %%
import graphviz

g = graphviz.Digraph('G', filename='hello.gv')

g.edge('paintings', 'painting')
g.edge('paintings', '-s')

g.edge('painting', 'paint')
g.edge('painting', '-ing')

g

# %%
import graphviz

g = graphviz.Digraph('G', filename='hello.gv')

g.edge('deactivate', 'de-')
g.edge('deactivate', 'V\nactivate')
# Possible word: de+activate ? --> # Any other example (de+verb)?
# Possible word:deactiv(e)+ate? --> Any other example?

g.edge('V\nactivate', 'A\nactive')
g.edge('V\nactivate', '-ate')

g.edge('A\nactive', 'V\nact')
g.edge('A\nactive', 'ive')
g

# %%
import graphviz

g = graphviz.Digraph('G', filename='hello.gv')

g.edge('disappearances', 'N\ndisappearance')
g.edge('disappearances', '-s')

g.edge('N\ndisappearance','V\ndisappear')
g.edge('N\ndisappearance','-ance')
# Possible word: dis+appearance ? --> # Any other example (dis+noun)?
# Possible word:disappear+ance? --> Any other example (verb+ance)?

g.edge('V\ndisappear', 'dis-')
g.edge('V\ndisappear', 'V\nappear')

g

# %% [markdown]
# ###Colors.py

# %%
import graphviz

g = graphviz.Graph(filename='colors.gv')

red, green, blue = 64, 224, 208
assert f'#{red:x}{green:x}{blue:x}' == '#40e0d0'

g.node('RGB: #40e0d0', style='filled', fillcolor='#40e0d0')

g.node('RGBA: #ff000042', style='filled', fillcolor='#ff000042')

g.node('HSV: 0.051 0.718 0.627', style='filled', fillcolor='0.051 0.718 0.627')

g.node('name: deeppink', style='filled', fillcolor='deeppink')

g

# %% [markdown]
# Gibe it a try [Nodes colored]

# %%
import graphviz

g = graphviz.Digraph('G', filename='hello.gv')

g.edge('disappearances', 'N\ndisappearance')
g.edge('disappearances', '-s')

g.edge('N\ndisappearance','V\ndisappear')
g.edge('N\ndisappearance','-ance')

g.edge('V\ndisappear', 'dis-')
g.edge('V\ndisappear', 'V\nappear')

g.node('dis-', style='filled', fillcolor='lightblue2')
g.node('-ance', style='filled', fillcolor='lightblue2')
g.node('-s', style='filled', fillcolor='goldenrod2')
g

# %% [markdown]
# # [Practice] Draw tree diagrams for the following words: construal, irreplaceablility, misconceive, indecipherable, redarken

# %% [markdown]
# #[Practice] Draw two tree diagrams for undarkenable to reveal its two meanings: 'able to be less dark' and 'unable to be made dark.'

# %% [markdown]
# ### 'able to be less dark' (hint: undarken - able)

# %%
import graphviz

u = graphviz.Digraph('unix', filename='unix.gv',
                     node_attr={'color': 'goldenrod2', 'style': 'filled'})
u.attr(size='20, 10')

u.edge('undarkenable', 'undarken')
u.edge('undarkenable', 'able')


u

# %% [markdown]
# ### 'uable to made dark' (hint: un - darkenable)

# %%
import graphviz

u = graphviz.Digraph('unix', filename='unix.gv',
                     node_attr={'color': '#ff000042', 'style': 'filled'})
u.attr(size='20, 10')

u.edge('undarkenable', 'un')
u.edge('undarkenable', 'darkenable')


u
